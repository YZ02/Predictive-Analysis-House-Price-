# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Load file

# %%
washington_file = r"C:\Users\PC\Downloads\Kaggle\Iowa House Price\train.csv"
washington_data = pd.read_csv(washington_file)

# %% [markdown]
# #### Get some necessary info

# %% [markdown]
# Overview of the first 5 rows

# %%
washington_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Shape of the data (rows, columns)

# %%
washington_data.shape
# Out:
# (1460, 81)

# %% [markdown]
# Rows and columns

# %%
# The variables/columns
washington_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# No. of columns
len(washington_data.columns)
# Out:
# 81

# %%
# No. of rows
len(washington_data.index)

# or df.shape[0] , change 0 t0 1 for columns
# Out:
# 1460

# %% [markdown]
# Accessing specific data

# %%
# Specific data (row 3, column 'SalePrice')
washington_data.loc[3,'SalePrice']
# Out:
# 140000

# %%
# Specific row and all columns (row 3)
washington_data.loc[3,:]  

#or just df.loc[3]
# Out:
# Id                     4
# MSSubClass            70
# MSZoning              RL
# LotFrontage         60.0
# LotArea             9550
#                   ...
# MoSold                 2
# YrSold              2006
# SaleType              WD
# SaleCondition    Abnorml
# SalePrice         140000
# Name: 3, Length: 81, dtype: object

# %%
# Specific column and all rows (columns 'SalePrice')
washington_data.loc[:,'SalePrice']

# or just df.loc['SalePrice'] / washington_data.SalePrice
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# Specific row and some columns
washington_data.iloc[0,0:3]
# Out:
# Id             1
# MSSubClass    60
# MSZoning      RL
# Name: 0, dtype: object

# %% [markdown]
# Missing Values

# %%
# Overview
washington_data.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
# How many null values in the data
washington_data.isnull().sum().sum()
# Out:
# 6965

# %%
# Which columns have null value
washington_data.columns[washington_data.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
# Total NaN at each column
washington_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# Total NaN at each row
for i in range(len(washington_data.index)) :
    print(" Total NaN in row", i + 1, ":",
          washington_data.iloc[i].isnull().sum())
# Out:
#  Total NaN in row 1 : 5
#  Total NaN in row 2 : 4
#  Total NaN in row 3 : 4
#  Total NaN in row 4 : 4
#  Total NaN in row 5 : 4
#  Total NaN in row 6 : 3
#  Total NaN in row 7 : 4
#  Total NaN in row 8 : 4
#  Total NaN in row 9 : 4
#  Total NaN in row 10 : 4
#  Total NaN in row 11 : 5
#  Total NaN in row 12 : 4
#  Total NaN in row 13 : 6
#  Total NaN in row 14 : 4
#  Total NaN in row 15 : 4
#  Total NaN in row 16 : 4
#  Total NaN in row 17 : 4
#  Total NaN in row 18 : 9
#  Total NaN in row 19 : 5
#  Total NaN in row 20 : 4
#  Total NaN in row 21 : 4
#  Total NaN in row 22 : 2
#  Total NaN in row 23 : 4
#  Total NaN in row 24 : 4
#  Total NaN in row 25 : 4
#  Total NaN in row 26 : 4
#  Total NaN in row 27 : 5
#  Total NaN in row 28 : 4
#  Total NaN in row 29 : 4
#  Total NaN in row 30 : 5
#  Total NaN in row 31 : 3
#  Total NaN in row 32 : 5
#  Total NaN in row 33 : 5
#  Total NaN in row 34 : 4
#  Total NaN in row 35 : 4
#  Total NaN in row 36 : 4
#  Total NaN in row 37 : 5
# ...

# %%
# Under specific column , display rows with null values
washington_data[pd.isnull(washington_data["Fence"])]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Checking if there's missing value for the target (SalePrice)
washington_data[pd.isnull(washington_data["SalePrice"])]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
# Say there's missing value, the rows containing null should be dropped
# washington_data.dropna(axis=0)

# %% [markdown]
# #### Target and Predictors

# %% [markdown]
# Setting target

# %%
y = washington_data.SalePrice

# %% [markdown]
# Setting Predictors

# %%
# Based on all data
x = washington_data.drop(['SalePrice'], axis=1)

# %%
# Based on selected variables/columns (features)
features = ['LotFrontage','LotArea','YrSold']
x = washington_data[features]

# %% [markdown]
# #### Splitting

# %%
from sklearn.model_selection import train_test_split
X_train_full, X_valid_full, y_train, y_valid = train_test_split(x, y, train_size=0.8, test_size=0.2,random_state=0)

# %% [markdown]
# #### MAE
#
# from sklearn.metrics import mean_absolute_error
#
# predicted_home_prices = melbourne_model.predict(X)
# mean_absolute_error(y, predicted_home_prices)
